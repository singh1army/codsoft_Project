# %% [markdown]
# # Project on IRIS Dataset

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %% [markdown]
# # Describe Iris Dataset

# %%
# Load the dataset
data = pd.read_csv('d://Data science/Python_DA/IRIS.csv')
df = data.copy()

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
# Information on Iris dataset: Value count of each columns:
print(f'The Iris dataset has {df.shape[0]} rows and {df.shape[1]} column \n{"="*50}')
print('\nThe attributes and their unique values are as below')
for i in df.columns:
    print(f'========== {i} ==========')
    print(df[i].value_counts().sort_values(ascending=False))
    print('- -'*20)
# Out:
# The Iris dataset has 150 rows and 5 column
# ...
#
# The attributes and their unique values are as below
# ========== sepal_length ==========
# sepal_length
# 5.0    10
# 6.3     9
# 5.1     9
# 5.7     8
# 6.7     8
# 5.8     7
# 5.5     7
# 6.4     7
# 6.0     6
# 5.6     6
# 4.9     6
# 6.1     6
# 5.4     6
# 4.8     5
# 6.5     5
# 5.2     4
# 4.6     4
# 6.9     4
# 7.7     4
# 6.2     4
# 5.9     3
# 4.4     3
# 7.2     3
# 6.8     3
# 6.6     2
# 4.7     2
# 7.1     1
# 4.5     1
# 4.3     1
# 5.3     1
# 7.6     1
# 7.0     1
# 7.3     1
# 7.4     1
# 7.9     1
# Name: count, dtype: int64
# - -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -
# ========== sepal_width ==========
# sepal_width
# 3.0    26
# 2.8    14
# 3.2    13
# 3.1    12
# 3.4    12
# 2.9    10
# 2.7     9
# 2.5     8
# 3.5     6
# 3.3     6
# 3.8     6
# 2.6     5
# 2.3     4
# 3.7     3
# 2.4     3
# 2.2     3
# 3.6     3
# 3.9     2
# 4.4     1
# 4.0     1
# 4.1     1
# 4.2     1
# 2.0     1
# ...

# %%
df['species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
print(f'Checking Null values in Isis data set:\n{df.isnull().sum()}\n{"-"*20}\nDuplicated value in iris dataset: {df.duplicated().sum()}')
# Out:
# Checking Null values in Isis data set:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64
# --------------------
# Duplicated value in iris dataset: 3

# %% [markdown]
# # Data Exploring and Visulization

# %%
df['species'].value_counts()
# Out:
# species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
sns.scatterplot(data=df, x="sepal_length", y="sepal_width",hue="species")
plt.show()

# %%
sns.scatterplot(data=df, x="petal_length", y="petal_width",hue="species")
plt.show()

# %%
plot = px.scatter(df,x=df['sepal_length'], y=df['sepal_length'],color=df['species'])
plot.show()

# %%
plot = px.scatter(df,x=df['petal_length'], y=df['petal_width'], color=df['species'])
plot.show()

# %%
# Pairplot to visualize relationships
sns.pairplot(df,hue="species")
plt.show()

# %% [markdown]
# # Label Encoding and model selection

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder = LabelEncoder()
df['species'] = label_encoder.fit_transform(df['species'])

# %% [raw]
# # we can also use one hot encoding to species column:
# df['species'] = df['species'].map({'Iris-setosa':0, 'Iris-versicolor':1, 'Iris-virginica':2'})

# %%
df.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width   species
# sepal_length      1.000000    -0.109369      0.871754     0.817954  0.782561
# sepal_width      -0.109369     1.000000     -0.420516    -0.356544 -0.419446
# petal_length      0.871754    -0.420516      1.000000     0.962757  0.949043
# petal_width       0.817954    -0.356544      0.962757     1.000000  0.956464
# species           0.782561    -0.419446      0.949043     0.956464  1.000000

# %%
df.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_6bcd8_row0_col0, #T_6bcd8_row1_col1, #T_6bcd8_row2_col2, #T_6bcd8_row3_col3, #T_6bcd8_row4_col4 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_6bcd8_row0_col1 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_6bcd8_row0_col2 {
#   background-color: #d44e41;
#   color: #f1f1f1;
# }
# #T_6bcd8_row0_col3 {
#   background-color: #e0654f;
#   color: #f1f1f1;
# }
# #T_6bcd8_row0_col4 {
#   background-color: #e46e56;
#   color: #f1f1f1;
# }
# #T_6bcd8_row1_col0, #T_6bcd8_row1_col2, #T_6bcd8_row1_col3, #T_6bcd8_row1_col4, #T_6bcd8_row2_col1, #T_6bcd8_row4_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_6bcd8_row2_col0 {
#   background-color: #da5a49;
#   color: #f1f1f1;
# }
# #T_6bcd8_row2_col3, #T_6bcd8_row3_col4 {
#   background-color: #be242e;
#   color: #f1f1f1;
# }
# #T_6bcd8_row2_col4, #T_6bcd8_row4_col2 {
#   background-color: #c12b30;
#   color: #f1f1f1;
# }
# #T_6bcd8_row3_col0 {
# ...

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %%
# All Possible Chart for density heat map of Iris Data:
colum =  ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']
com = [tuple([a,b]) for a in [i for i in colum] for b in [i for i in colum]]  # Possible column in iris dataset
print("All Possible Match: ",com)
for i, j in com:
    print(density_map(i,j),"\n")

def density_heat(a,b):
    fig = px.density_heatmap(df, x=a, y=b, marginal_x="rug", marginal_y="histogram")
    fig.show()
# Out:
# All Possible Match:  [('sepal_length', 'sepal_length'), ('sepal_length', 'sepal_width'), ('sepal_length', 'petal_length'), ('sepal_length', 'petal_width'), ('sepal_width', 'sepal_length'), ('sepal_width', 'sepal_width'), ('sepal_width', 'petal_length'), ('sepal_width', 'petal_width'), ('petal_length', 'sepal_length'), ('petal_length', 'sepal_width'), ('petal_length', 'petal_length'), ('petal_length', 'petal_width'), ('petal_width', 'sepal_length'), ('petal_width', 'sepal_width'), ('petal_width', 'petal_length'), ('petal_width', 'petal_width')]
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'sepal_length'}>,
#         <Axes: title={'center': 'sepal_width'}>],
#        [<Axes: title={'center': 'petal_length'}>,
#         <Axes: title={'center': 'petal_width'}>],
#        [<Axes: title={'center': 'species'}>, <Axes: >]], dtype=object)

# %%
# Make a copy of data so that data after encoding will safe:
data_2nd = df.copy(deep=True)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import VotingClassifier

# %%
# working with 2nd data
# Features and target variable
X = df.drop('species', axis=1)
y = df['species']

# Split into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
print(f'Shape of X_train: {X_train.shape}\nShape of X_test: {X_test.shape}\nShape of y_train: {y_train.shape}\nShape of y_test: {y_test.shape}')
# Out:
# Shape of X_train: (105, 4)
# Shape of X_test: (45, 4)
# Shape of y_train: (105,)
# Shape of y_test: (45,)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# Initialize models
models = {
    'Logistic Regression': LogisticRegression(),
    'K-Nearest Neighbors': KNeighborsClassifier(),
    'Support Vector Machine': SVC(),
    'Decision Tree': DecisionTreeClassifier(),
    'Random Forest': RandomForestClassifier(),
    'Gradient Boosting': GradientBoostingClassifier(),
    'Naive Bayes': GaussianNB(),
    'MLP Classifier': MLPClassifier(max_iter=1000),
    'LDA': LinearDiscriminantAnalysis()
}

# Train and evaluate models
results = {}
for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    results[name] = accuracy
    print(f'{name} Accuracy: {accuracy:.4f}')
    print(classification_report(y_test, y_pred))
    print(confusion_matrix(y_test, y_pred))
    print('-' * 40)
# Out:
# Logistic Regression Accuracy: 1.0000
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45
#
# [[19  0  0]
#  [ 0 13  0]
#  [ 0  0 13]]
# ----------------------------------------
# K-Nearest Neighbors Accuracy: 1.0000
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45
#
# [[19  0  0]
#  [ 0 13  0]
# ...

# %%
results
# Out:
# {'Logistic Regression': 1.0,
#  'K-Nearest Neighbors': 1.0,
#  'Support Vector Machine': 1.0,
#  'Decision Tree': 1.0,
#  'Random Forest': 1.0,
#  'Gradient Boosting': 1.0,
#  'Naive Bayes': 0.9777777777777777,
#  'MLP Classifier': 1.0,
#  'LDA': 1.0}

# %%
# Model Comparision:
import matplotlib.pyplot as plt

model_names = list(results.keys())
model_scores = list(results.values())

plt.figure(figsize=(10, 5))
plt.barh(model_names, model_scores, color='skyblue')
plt.xlabel('Accuracy')
plt.title('Model Comparison')
plt.show()
